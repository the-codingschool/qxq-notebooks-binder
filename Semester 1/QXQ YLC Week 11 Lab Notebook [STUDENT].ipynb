# %% [markdown]
# # **Lab 11: Review**
# ---
#
# ### **Description**
# In today's lab, we will review concepts from the first semester.
#
# <br>
#
# ### **Structure**
# **Part 1**: [The Qubit Object](#p1)
#
# **Part 2**: [Programming With Python](#p2)
#
# **Part 3**: [Quantum Circuits](#p3)
#
# **Part 4**: [B92 [ADVANCED]](#p4)
#
#
# <br>
#
# ### **Resources**
# * [Python Basics Cheat Sheet](https://docs.google.com/document/d/1uLao-xKh3tYIiCYyiqf7oas4qTlr5XYKQ0QpzX_Xzag/edit?usp=drive_link)
# * [Cirq Basics Cheat Sheet](https://docs.google.com/document/d/1j0vEwtS6fK-tD1DWAPry4tJdxEiq8fwMtXuYNGRhK_M/edit?usp=drive_link)
# * [BB84 Cheat Sheet](https://docs.google.com/document/d/1FTBVWQsRVPvuP5e4lo3D62F0NOyfA1qIIPrDnocV6nc/edit?usp=drive_link)
#
# <br>
#
# **Before starting, run the code below to import all necessary functions and libraries.**

# %%
# @title
# !pip install cirq --quiet
import cirq
import cirq
import numpy as np
import cirq_web.bloch_sphere as bloch_sphere
import matplotlib.pyplot as plt
def binary_labels(num_qubits):
    return [bin(x)[2:].zfill(num_qubits) for x in range(2 ** num_qubits)]
plt.rcParams.update({'font.size': 8})
from random import choices
print("Libraries imported successfully!")

# %% [markdown]
# <a name="p1"></a>
#
# ---
# ## **Part 1: The Qubit Object**
# ---
# In this part, you will review how to work with and represent the qubit object in Cirq.

# %% [markdown]
# ### **Problem #1.1**
# **Together**, create and output a vector representing a qubit in the $|0\rangle$ state.

# %%
vec = # COMPLETE THIS CODE

# %% [markdown]
# ### **Problem #1.2**
# **Together**, output your vector from Problem #1.1 in ket notation.

# %%
cirq.dirac_notation(# COMPLETE THIS CODE

# %% [markdown]
# ###**Problem #1.3**
# **Together**, place your vector from Problem #1.1 on the Bloch Sphere.

# %%
bloch_sphere.BlochSphere(state_vector = # COMPLETE THIS CODE

# %% [markdown]
# ###**Problem #1.4**
# **Independently**, create and output a vector representing a qubit in the $|1\rangle$ state.

# %%
vec = # COMPLETE THIS CODE

# %% [markdown]
# ### **Problem #1.5**
# **Independently**, output your vector from Problem #1.4 in ket notation.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# ###**Problem #1.6**
# **Independently**, place your vector from Problem #1.4 on the Bloch Sphere.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# ###**Problem #1.7**
# **Independently**, create and output a vector representing a qubit in the $\frac{1}{\sqrt{2}}|0\rangle + \frac{1}{\sqrt{2}}|1\rangle$ state.

# %%
vec = # COMPLETE THIS CODE

# %% [markdown]
# ### **Problem #1.8**
# **Independently**, output your vector from Problem #1.7 in ket notation.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# ###**Problem #1.9**
# **Independently**, place your vector from Problem #1.7 on the Bloch Sphere.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# <a name="p2"></a>
#
# ---
# ## **Part 2: Programming with Python**
# ---
# In this part, you will review how to code using python.

# %% [markdown]
# ### **Problem #2.1**
# **Together**, debug the code below.

# %%
my_list = ["red", "yellow", "blue", "orange", "purple", "green"]
My_List[3]

# %% [markdown]
# ### **Problem #2.2**
# **Independently**, debug the code below.

# %%
animal = "tiger"
print("My favorite animal is the", "animal")

# %% [markdown]
# ### **Problem #2.3**
# **Independently**, debug the code below.

# %%
vec = [1/np.sqrt(2), -1/np.sqrt(2)]
bloch_sphere.BlochSphere(vec)

# %% [markdown]
# ### **Problem #2.4**
# **Independently**, debug the code below.

# %%
my_qubits = cirq.NamedQubit.range(3, prefix ="q")
my_circuit = cirq.Circuit()
my_circuit.append(cirq.measure(my_qubits[1]))
my_circuit.append(cirq.measure(my_qubits[2]))
my_circuit.append(cirq.measure(my_qubits[3]))
my_circuit

# %% [markdown]
# <a name="p3"></a>
#
# ---
# ## **Part 3: Quantum Circuits**
# ---
# In this part, you will review how to create and work with quantum circuits in Cirq.

# %% [markdown]
# ### **Problem #3.1**
# **Together**, create 3 qubits and an empty circuit.

# %%
my_qubits = # COMPLETE THIS CODE
my_circuit = # COMPLETE THIS CODE

# %% [markdown]
# ###**Problem #3.2**
# **Together**, append an X gate on the first qubit, an H gate on the second qubit, and both and X and H gate on the final qubit. Add a measurement gate on all three qubits.

# %%
my_circuit.append(# COMPLETE THIS CODE
my_circuit.append(# COMPLETE THIS CODE
my_circuit.append(# COMPLETE THIS CODE
my_circuit.append(# COMPLETE THIS CODE
my_circuit.append(# COMPLETE THIS CODE
my_circuit

# %% [markdown]
# ###**Problem #3.3**
# **Together**, simulate the results of the circuit from Problem #3.3 100 times.

# %%
sim = # COMPLETE THIS CODE
result = # COMPLETE THIS CODE

# %% [markdown]
# ###**Problem #3.4**
# **Together**, plot the results from Problem #3.3 on a histogram.

# %%
hist = cirq.plot_state_histogram(result, plt.subplot(), title = 'Qubit States', xlabel = 'States', ylabel = 'Occurrences', tick_label=binary_labels(# COMPLETE THIS CODE

plt.show()

# %% [markdown]
# ###**Problem #3.5**
# **Independently**, create 4 qubits, create an empty circuit, apply an H gate to each qubit, apply a Z gate to the first qubit, and apply a measurement to each qubit. Output your circuit.

# %%
my_qubits = # COMPLETE THIS CODE

# %% [markdown]
# ###**Problem #3.6**
# **Independently**, simulate the results of your circuit from Problem #3.5 100 times. Plot the results on a histogram.

# %%
sim = # COMPLETE THIS CODE

hist = cirq.plot_state_histogram(result, plt.subplot(), title = 'Qubit States', xlabel = 'States', ylabel = 'Occurrences', tick_label=binary_labels(# COMPLETE THIS CODE
plt.show()

# %% [markdown]
# ###**Problem #3.7**
# **Independently**, create two qubits. Create an empty circuit. Append a gate to the first qubit such that it is in a superposition. Then, modify the circuit such that the second qubit will always be in the opposite state as the first. Output your circuit.

# %%
my_qubits = # COMPLETE THIS CODE

# %% [markdown]
# ###**Problem #3.8**
# **Independently**, output the final state vector of your qubits from Problem #3.7 in ket notation.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# ###**Problem #3.9**
# **Independently**, append a measurement to each of your qubits from Problem #3.7. Simulate the results of the circuit 1,000 times and output the results on a histogram. Are the results what you expected?

# %%
# COMPLETE THIS CODE

sim = # COMPLETE THIS CODE

hist = cirq.plot_state_histogram(result, plt.subplot(), title = 'Qubit States', xlabel = 'States', ylabel = 'Occurrences', tick_label=binary_labels(# COMPLETE THIS CODE
plt.show()

# %% [markdown]
# <a name="p4"></a>
#
# ---
# ## **Part 4: B92 [ADVANCED]**
# ---
# In this part, you will work with B92, a different QKD protocol.

# %% [markdown]
# ---
# ### **Problem 4.1: Alice and Bob**
# ---
#
# In this part, we will see how to implement the B92 Protocol.

# %% [markdown]
# ####**Setup**
# **Independently**, define a dictionary called `basis_gates` that specify which gates to apply based on the basis. Then, create a list of `NamedQubit`s that is `num_bits` long and has the prefix `q`.
#
# **Run the code below to accomplish this.**

# %%
basis_gates = {'Z': cirq.I, 'X': cirq.H}

num_bits = 20
qubits = cirq.NamedQubit.range(num_bits, prefix = 'q')

# %% [markdown]
# ---
# #### **Phase #1: Alice Sends**
# ---

# %% [markdown]
# ####**Step 1: Alice Chooses Bases**
# **Independently**, use python's `choices(...)` function to create Alice's `num_bits` basis choices.

# %%
alice_bases = # COMPLETE THIS CODE

print('\nAlice\'s randomly chosen bases: ', alice_bases)

# %% [markdown]
# ####**Step 2: Alice Creates Qubits**
# **Independently**, create Alice's qubits based on her choice of bases. Complete the code below so that the appropriate gates are appended to `alice_circuit` within the loop.

# %%
alice_circuit = cirq.Circuit()

for bit in range(num_bits):

  basis_value = alice_bases[# COMPLETE THIS CODE
  basis_gate = basis_gates[# COMPLETE THIS CODE

  qubit = qubits[# COMPLETE THIS CODE
  alice_circuit.append(basis_gate(# COMPLETE THIS CODE

# %% [markdown]
# ####**Step 3: Alice Sends Qubits**
# This step does not require any code.

# %% [markdown]
# ---
# #### **Phase #2: Bob Receives**
# ---

# %% [markdown]
# ####**Step 4: Bob Randomly Chooses Bases**
# **Independently**, randomly choose Bob's `num_bits` bases and apply the appropriate gates to the qubits he received, `qubits`. Complete the code below to accomplish this for each qubit.

# %%
bob_bases = # COMPLETE THIS CODE
print('\nBob\'s randomly chosen bases: ', bob_bases)

bob_circuit = cirq.Circuit()
for bit in range(# COMPLETE THIS CODE

  basis_value = bob_bases[# COMPLETE THIS CODE
  basis_gate = basis_gates[# COMPLETE THIS CODE

  qubit = qubits[# COMPLETE THIS CODE
  bob_circuit.append(basis_gate(# COMPLETE THIS CODE
bob_circuit

# %% [markdown]
# ####**Step 5: Bob Measures His Qubits**
# **Independently**, make a measurement of all of the qubits for Bob. Complete the code below to append this action to `bob_circuit`. Ensure the measure method is given the parameter `key = 'bob key'` so that we can easily retrieve this result later.

# %%
bob_circuit.append(# COMPLETE THIS CODE

print(bob_circuit)

# %% [markdown]
# ####**Step 6: Bob Creates a Key**
# **Independently**, run the code below to make an initial key for Bob.

# %%
bb84_circuit = alice_circuit + bob_circuit

sim = cirq.Simulator()
results = sim.run(bb84_circuit)
bob_key = results.measurements['bob key'][0]

print('\nBob\'s initial key: ', bob_key)

# %% [markdown]
# ---
# #### **Phase #3: Alice and Bob Compare**
# ---

# %% [markdown]
# ####**Step 7: Alice and Bob Compare**
# **Independently**, compare Alice's and Bob's randomly selected bases.
#
# **Run the code below to accomplish this step.**

# %%
final_alice_key = []
final_bob_key = []

for bit in range(num_bits):
  if bob_key[bit] == 1:
    if alice_bases[bit] == 'Z':
      final_alice_key.append(0)
    if alice_bases[bit] == 'X':
      final_alice_key.append(1)
    if bob_bases[bit] == 'Z':
      final_bob_key.append(1)
    if bob_bases[bit] == 'X':
      final_bob_key.append(0)

print('\nAlice\'s key: ', final_alice_key)
print('Bob\'s key: ', final_bob_key)

# %% [markdown]
# #### **Step #8: Alice and Bob Compare the First Bits in Their Key**
#
# **Independently**, compare the first few bits in Alice's and Bob's key to ensure the protocol was successful.
#
# <br>
#
# **Run the code below to accomplish this.**

# %%
num_bits_to_compare = int(len(final_alice_key) * .5)
if final_alice_key[0:num_bits_to_compare] == final_bob_key[0:num_bits_to_compare]:
  final_alice_key = final_alice_key[num_bits_to_compare:]
  final_bob_key = final_bob_key[num_bits_to_compare:]

  print('\n\nWe can use our keys!')
  print('Alice Key: ', final_alice_key)
  print('Bob Key: ', final_bob_key)

else:
  print('\n\nEve was listening, we need to use a different channel!')

# %% [markdown]
# ---
# ### **Problem 4.2: Alice, Bob, and Eve's Measurement Attack**
# ---
#
# Now, we will modify this code to introduce Eve, who will be performing a measurement attack.

# %% [markdown]
# ####**Setup**
# **Independently**, define a dictionary called `basis_gates` that specify which gates to apply based on the basis. Then, create a list of `NamedQubit`s that is `num_bits` long and has the prefix `q`.

# %%
basis_gates = {# COMPLETE THIS CODE

num_bits = 20
qubits = cirq.NamedQubit.range(num_bits, prefix = 'q')

# %% [markdown]
# ---
# #### **Phase #1: Alice Sends**
# ---

# %% [markdown]
# ####**Step 1: Alice Chooses Bases**
# **Independently**, use python's `choices(...)` function to create Alice's `num_bits` basis choices.

# %%
alice_bases = # COMPLETE THIS CODE

print('\nAlice\'s randomly chosen bases: ', alice_bases)

# %% [markdown]
# ####**Step 2: Alice Creates Qubits**
# **Independently**, create Alice's qubits based on her choice of bases. Complete the code below so that the appropriate gates are appended to `alice_circuit` within the loop.

# %%
alice_circuit = cirq.Circuit()

for bit in range(num_bits):

  basis_value = alice_bases[# COMPLETE THIS CODE
  basis_gate = basis_gates[# COMPLETE THIS CODE

  qubit = qubits[# COMPLETE THIS CODE
  alice_circuit.append(basis_gate(# COMPLETE THIS CODE

# %% [markdown]
# ####**Step 3: Alice Sends Qubits**
# This step does not require any code.

# %% [markdown]
# ---
# #### **Phase #2: Eve Receives**
# ---

# %% [markdown]
# #### **Step #4: Eve Randomly Chooses Bases**
#
# For this attack, Eve does not try to guess bases, so no code is required.

# %% [markdown]
# #### **Step #5: Eve Measures the Qubits**
# **Independently**, make a measurement of all of the qubits for Eve. Complete the code below to append this action to `eve_circuit`. Ensure the measure method is given the parameter `key = 'eve key'` so that we can easily retrieve this result later.

# %%
eve_circuit = cirq.Circuit()
eve_circuit.append(# COMPLETE THIS CODE

# %% [markdown]
# #### **Step #6: Eve Creates a Key**
#
# **Independently**, create a key for Eve from the mesurement result of each qubit.
#
# <br>
#
# **Run the code below to accomplish this step.**

# %%
eve_intercept_circuit = alice_circuit + eve_circuit

sim = cirq.Simulator()
results = sim.run(eve_intercept_circuit)
eve_key = results.measurements['eve key'][0]

print('\nEve\'s initial key: ', eve_key)

# %% [markdown]
# #### **Eve Repeats Step #3 to Fool Bob**
#
# **Run the code below to accomplish this step.**

# %%
encode_gates = {0: cirq.I, 1: cirq.X}
alice_circuit = cirq.Circuit()

for bit in range(num_bits):

  encode_value = eve_key[bit]
  encode_gate =encode_gates[encode_value]



  qubit = qubits[bit]
  alice_circuit.append(encode_gate(qubit))

print('\nAlice\'s Phase 1 circuit after Eve\'s interception:\n', alice_circuit)

# %% [markdown]
# ---
# #### **Phase #2: Bob Receives**
# ---

# %% [markdown]
# ####**Step 4: Bob Randomly Chooses Bases**
# **Independently**, randomly choose Bob's `num_bits` bases and apply the appropriate gates to the qubits he received, `qubits`. Complete the code below to accomplish this for each qubit.

# %%
bob_bases = # COMPLETE THIS CODE
print('\nBob\'s randomly chosen bases: ', bob_bases)

bob_circuit = cirq.Circuit()
for bit in range(# COMPLETE THIS CODE

  basis_value = bob_bases[# COMPLETE THIS CODE
  basis_gate = basis_gates[# COMPLETE THIS CODE

  qubit = qubits[# COMPLETE THIS CODE
  bob_circuit.append(basis_gate(# COMPLETE THIS CODE
bob_circuit

# %% [markdown]
# ####**Step 5: Bob Measures His Qubits**
# **Independently**, make a measurement of all of the qubits for Bob. Complete the code below to append this action to `bob_circuit`. Ensure the measure method is given the parameter `key = 'bob key'` so that we can easily retrieve this result later.

# %%
bob_circuit.append(# COMPLETE THIS CODE

print(bob_circuit)

# %% [markdown]
# ####**Step 6: Bob Creates a Key**
# **Independently**, run the code below to make an initial key for Bob.

# %%
bb84_circuit = alice_circuit + bob_circuit

sim = cirq.Simulator()
results = sim.run(bb84_circuit)
bob_key = results.measurements['bob key'][0]

print('\nBob\'s initial key: ', bob_key)

# %% [markdown]
# ---
# #### **Phase #3: Alice and Bob Compare**
# ---

# %% [markdown]
# ####**Step 7: Alice and Bob Compare**
# **Independently**, compare Alice's and Bob's randomly selected bases. Complete the code below to accomplish this.
#
# **Run the code below to accomplish this step.**

# %%
final_alice_key = []
final_bob_key = []

for bit in range(num_bits):
  if bob_key[bit] == 1:
    if alice_bases[bit] == 'Z':
      final_alice_key.append(0)
    if alice_bases[bit] == 'X':
      final_alice_key.append(1)
    if bob_bases[bit] == 'Z':
      final_bob_key.append(1)
    if bob_bases[bit] == 'X':
      final_bob_key.append(0)

print('\nAlice\'s key: ', final_alice_key)
print('Bob\'s key: ', final_bob_key)

# %% [markdown]
# #### **Step #8: Alice and Bob Compare the First Bits in Their Key**
#
# **Independently**, compare the first few bits in Alice's and Bob's key to ensure the protocol was successful.
#
# <br>
#
# **Run the code below to accomplish this.**

# %%
num_bits_to_compare = int(len(final_alice_key) * .5)
if final_alice_key[0:num_bits_to_compare] == final_bob_key[0:num_bits_to_compare]:
  final_alice_key = final_alice_key[num_bits_to_compare:]
  final_bob_key = final_bob_key[num_bits_to_compare:]

  print('\n\nWe can use our keys!')
  print('Alice Key: ', final_alice_key)
  print('Bob Key: ', final_bob_key)

else:
  print('\n\nEve was listening, we need to use a different channel!')

# %% [markdown]
# # End of Notebook
#
# ---
# © 2023 The Coding School, All rights reserved
