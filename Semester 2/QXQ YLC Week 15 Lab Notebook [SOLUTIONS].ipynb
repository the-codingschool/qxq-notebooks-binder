# %% [markdown]
# # **Lab 14: Complexity of Algorithms**
# ---
#
# ### **Description**
# Today, we will work with two of the most famous classical search algorithms: linear and binary search. We will implement and analyze their performance.
#
#
#
# <br>
#
# ### **Structure**
# ### **Structure**
# **Part 1**: [Linear Search](#p1)
#
# **Part 2**: [Binary Search](#p2)
#
#
# <br>
#
# ### **Learning Objectives**
# By the end of this lab, you will:
# * Recognize how to compare algorithms using big-O notation.
# * Recognize the limits of classical search algorithms for unordered lists.
#
#
# <br>
#
# ### **Resources**
# * [Linear Search as a Dance](http://www.youtube.com/watch?v=-PuqKbu9K3U)
#
# * [Binary Search as a Dance](http://www.youtube.com/watch?v=wz7XgKowJIg)
#
#
# <br>
#
# **Before starting, run the code below to import all necessary functions and libraries.**

# %%
# @title
# Importing other python libraries
import random
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# <a name="p1"></a>
#
# ---
# ## **Part 1: Linear Search**
# ---
#
# In this section, we will implement and analyze the linear search algorithm.

# %% [markdown]
# #### **Problem #1.1**
#
# **Together**, let's run the code below to implement linear search for a list of numbers. We will use the following variables:
# * `list_items`: A list of numbers from 0 to 49 that we will search through.
# * `marked_item`: A randomly selected number from the list that we will search for.
# * `number_queries`: A count of how many times we need to query the list to find the marked item.

# %%
list_items = range(50)
marked_item = random.choice(list_items)

print(list_items)
print(marked_item)

number_queries = 0
for item in list_items:

    number_queries = number_queries + 1

    if item == marked_item:
        print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break
# Out:
# range(0, 50)
# 13
# 13 has been found in 14 queries.

# %% [markdown]
# ###### **Solution**

# %%
list_items = range(50)

marked_item = random.choice(list_items)
number_queries = 0
for item in list_items:

    number_queries = number_queries + 1

    if item == marked_item:
        print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break
# Out:
# 12 has been found in 13 queries.

# %% [markdown]
# #### **Problem #1.2**
#
# **Together**, let's complete the code below to run our linear search many times to find the *worst number of queries*. We will use the following additional variables:
# * `number_trials`: The number of times to repeat the linear search.
# * `worst_query`: The most number of queries we had to make across all trials.

# %%
number_trials = 1000
worst_query = 0
list_items = range(50)

for i in range(number_trials):

  marked_item = random.choice(list_items)
  number_queries = 0
  for item in list_items:

      number_queries = # COMPLETE THIS LINE

      if item == marked_item:
          print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
          break

  worst_query = max(worst_query, number_queries)

print("Worst number of queries: " + str(worst_query))

# %% [markdown]
# ###### **Solution**

# %%
number_trials = 10
worst_query = 0
list_items = range(50)

for i in range(number_trials):

  marked_item = random.choice(list_items)
  number_queries = 0
  for item in list_items:

      number_queries = number_queries + 1

      if item == marked_item:
        print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

  worst_query = max(worst_query, number_queries)

print("Worst number of queries: " + str(worst_query))
# Out:
# 20 has been found in 21 queries.
# 41 has been found in 42 queries.
# 8 has been found in 9 queries.
# 32 has been found in 33 queries.
# 4 has been found in 5 queries.
# 20 has been found in 21 queries.
# 15 has been found in 16 queries.
# 35 has been found in 36 queries.
# 30 has been found in 31 queries.
# 12 has been found in 13 queries.
# Worst number of queries: 42

# %% [markdown]
# #### **Problem #1.3**
#
# **Together**, let's put this code into a function called `linear_search` such that it:
# * Takes `n` as input parameters.
# * Runs the code we wrote in Exercise #2 such that there are `n` items in `list_items`.
# * Returns the worst number of queries instead of printing it.

# %%
def linear_search(n):

  # COMPLETE THIS CODE

  return # COMPLETE THIS CODE

# %% [markdown]
# ###### **Solution**

# %%
def linear_search(n):

  number_trials = 10
  worst_query = 0
  list_items = range(n)

  for i in range(number_trials):

    marked_item = random.choice(list_items)
    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      if item == marked_item:
        #print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# ### **Problem #1.4**
#
# **Together**, let's graph the worst number of queries for list sizes from 100 to 10000.

# %%
linear_queries = []
ns = range(100, 10000, 100)
for n in ns:
  linear_queries += [# COMPLETE THIS LINE

plt.scatter(ns, linear_queries, label = "linear")
plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear Search Worst Number of Queries with Increasing List Size")

plt.plot()
# Out:
#   File "<ipython-input-11-b93cfee08798>", line 8
#     plt.ylabel("Worst Number of Queries")
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ###### **Solution**

# %%
linear_queries = []
ns = range(100, 10000, 100)
for n in ns:
  linear_queries += [linear_search(n)]

plt.scatter(ns, linear_queries, label = "linear")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# []

# %% [markdown]
# <a name="p2"></a>
#
# ---
# ## **Part 2: Binary Search**
# ---
#
# In this section, we will implement and analyze the binary search algorithm. We will also visually compare it to the linear search algorithm we implemented above.

# %% [markdown]
# #### **Problem #2.1**
#
# **Together**, let's complete the code below to implement binary search for a list of numbers. We will use the following variables:
# * `list_items`: A list of numbers from 0 to 49 that we will search through.
# * `marked_item`: A randomly selected number from the list that we will search for.
# * `number_queries`: A count of how many times we need to query the list to find the marked item.

# %%
list_items = range(50)
marked_item = random.choice(list_items)

left = 0
right = len(list_items) - 1

number_queries = 0
for item in list_items:

  number_queries = # COMPLETE THIS LINE

  middle = int((left + right)/2)
  if list_items[middle] > marked_item:
    # COMPLETE THIS LINE
  elif list_items[middle] < marked_item:
    # COMPLETE THIS LINE
  else:
    print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
    break

# %% [markdown]
# ###### **Solution**

# %%
list_items = range(50)
marked_item = random.choice(list_items)

left = 0
right = len(list_items) - 1

number_queries = 0
for item in list_items:

  number_queries = number_queries + 1

  middle = int((left + right)/2)
  if list_items[middle] > marked_item:
    right = middle
  elif list_items[middle] < marked_item:
    left = middle
  else:
    print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
    break
# Out:
# 48 has been found in 6 queries.

# %% [markdown]
# #### **Problem #2.2**
#
# **Independently**, complete the code below to run our binary search many times to find the *worst number of queries*. You will use the following additional variables:
# * `number_trials`: The number of times to repeat the binary search.
# * `worst_query`: The most number of queries we had to make across all trials.

# %%
number_trials = 10
worst_query = 0
list_items = range(50)

for i in range(number_trials):

  # ADD THE CODE FROM EXERCISE #1 HERE

  worst_query = # COMPLETE THIS LINE

print("Worst number of queries: " + str(worst_query))

# %% [markdown]
# ###### **Solution**

# %%
number_trials = 10
worst_query = 0
list_items = range(50)

for i in range(number_trials):

  marked_item = random.choice(list_items)

  left = 0
  right = len(list_items) - 1

  number_queries = 0
  for item in list_items:

    number_queries = number_queries + 1

    middle = int((left + right)/2)
    if list_items[middle] > marked_item:
      right = middle
    elif list_items[middle] < marked_item:
      left = middle
    else:
      print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
      break

  worst_query = max(worst_query, number_queries)

print("Worst number of queries: " + str(worst_query))
# Out:
# 25 has been found in 5 queries.
# 12 has been found in 2 queries.
# 45 has been found in 4 queries.
# 10 has been found in 5 queries.
# 28 has been found in 5 queries.
# 33 has been found in 4 queries.
# 11 has been found in 6 queries.
# 42 has been found in 3 queries.
# 46 has been found in 6 queries.
# 12 has been found in 2 queries.
# Worst number of queries: 6

# %% [markdown]
# #### **Problem #2.3**
#
# **Independently**, put this code into a function called `binary_search` such that it:
# * Takes `n` as input parameters.
# * Runs the code we wrote in Exercise #2 such that there are `n` items in `list_items`.
# * Returns the worst number of queries instead of printing it.

# %%
def binary_search(n):

  # ADD THE CODE FROM EXERCISE #1 HERE

  return # COMPLETE THIS LINE

# %% [markdown]
# ###### **Solution**

# %%
def binary_search(n):

  number_trials = 10
  worst_query = 0
  list_items = range(n)

  for i in range(number_trials):

    marked_item = random.choice(list_items)

    left = 0
    right = len(list_items) - 1

    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      middle = int((left + right)/2)
      if list_items[middle] > marked_item:
        right = middle
      elif list_items[middle] < marked_item:
        left = middle
      else:
        print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# ---
# ####**Wait for your instructor to continue.**
#
# ---

# %% [markdown]
# #### **Problem #2.4**
#
# **Together**, graph the worst number of queries for list sizes from 100 to 10000.

# %%
binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  # COMPLETE THIS LINE

plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()

# %% [markdown]
# ###### **Solution**

# %%
# Importing  python libraries
import random
import matplotlib.pyplot as plt



binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  binary_queries += [binary_search(n)]

plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# 78 has been found in 6 queries.
# 53 has been found in 6 queries.
# 47 has been found in 6 queries.
# 2 has been found in 7 queries.
# 54 has been found in 7 queries.
# 49 has been found in 1 queries.
# 48 has been found in 7 queries.
# 35 has been found in 7 queries.
# 38 has been found in 7 queries.
# 27 has been found in 5 queries.
# 155 has been found in 5 queries.
# 196 has been found in 8 queries.
# 157 has been found in 8 queries.
# 159 has been found in 7 queries.
# 128 has been found in 7 queries.
# 170 has been found in 6 queries.
# 186 has been found in 4 queries.
# 155 has been found in 5 queries.
# 173 has been found in 8 queries.
# 89 has been found in 6 queries.
# 274 has been found in 9 queries.
# 264 has been found in 8 queries.
# 96 has been found in 6 queries.
# 138 has been found in 9 queries.
# 168 has been found in 8 queries.
# 109 has been found in 8 queries.
# 75 has been found in 8 queries.
# 249 has been found in 8 queries.
# 109 has been found in 8 queries.
# 203 has been found in 8 queries.
# 0 has been found in 9 queries.
# 352 has been found in 7 queries.
# 257 has been found in 9 queries.
# 138 has been found in 9 queries.
# 78 has been found in 8 queries.
# 4 has been found in 8 queries.
# 394 has been found in 9 queries.
# 237 has been found in 8 queries.
# 42 has been found in 6 queries.
# 57 has been found in 9 queries.
# 191 has been found in 8 queries.
# 414 has been found in 8 queries.
# 345 has been found in 9 queries.
# 5 has been found in 8 queries.
# 232 has been found in 9 queries.
# 324 has been found in 8 queries.
# 127 has been found in 7 queries.
# 21 has been found in 8 queries.
# 64 has been found in 9 queries.
# 112 has been found in 7 queries.
# 565 has been found in 7 queries.
# 289 has been found in 6 queries.
# 473 has been found in 8 queries.
# 230 has been found in 8 queries.
# 44 has been found in 9 queries.
# 182 has been found in 9 queries.
# 458 has been found in 6 queries.
# 289 has been found in 6 queries.
# 390 has been found in 9 queries.
# 72 has been found in 9 queries.
# 107 has been found in 10 queries.
# 270 has been found in 9 queries.
# 279 has been found in 10 queries.
# 54 has been found in 6 queries.
# 190 has been found in 9 queries.
# 199 has been found in 10 queries.
# 427 has been found in 8 queries.
# 29 has been found in 8 queries.
# 523 has been found in 10 queries.
# 667 has been found in 9 queries.
# 420 has been found in 8 queries.
# 274 has been found in 5 queries.
# 726 has been found in 10 queries.
# 282 has been found in 10 queries.
# 551 has been found in 10 queries.
# 80 has been found in 7 queries.
# 311 has been found in 6 queries.
# 443 has been found in 9 queries.
# 683 has been found in 8 queries.
# 97 has been found in 9 queries.
# 246 has been found in 9 queries.
# 589 has been found in 5 queries.
# 884 has been found in 6 queries.
# 385 has been found in 7 queries.
# 842 has been found in 4 queries.
# 790 has been found in 10 queries.
# 627 has been found in 8 queries.
# 462 has been found in 10 queries.
# 528 has been found in 10 queries.
# 155 has been found in 9 queries.
# 948 has been found in 10 queries.
# 207 has been found in 9 queries.
# 375 has been found in 9 queries.
# 138 has been found in 10 queries.
# 146 has been found in 10 queries.
# 413 has been found in 10 queries.
# 547 has been found in 9 queries.
# 561 has been found in 4 queries.
# 213 has been found in 8 queries.
# 593 has been found in 10 queries.
# 329 has been found in 8 queries.
# 502 has been found in 10 queries.
# 18 has been found in 10 queries.
# 547 has been found in 10 queries.
# 79 has been found in 10 queries.
# 506 has been found in 10 queries.
# 384 has been found in 7 queries.
# 153 has been found in 11 queries.
# 756 has been found in 10 queries.
# 599 has been found in 11 queries.
# 1005 has been found in 11 queries.
# 964 has been found in 7 queries.
# 486 has been found in 5 queries.
# 802 has been found in 9 queries.
# 480 has been found in 11 queries.
# 267 has been found in 9 queries.
# 413 has been found in 9 queries.
# 305 has been found in 9 queries.
# 831 has been found in 10 queries.
# 292 has been found in 10 queries.
# 782 has been found in 9 queries.
# 98 has been found in 9 queries.
# 1033 has been found in 11 queries.
# 629 has been found in 10 queries.
# 812 has been found in 10 queries.
# 1203 has been found in 9 queries.
# 41 has been found in 10 queries.
# 994 has been found in 6 queries.
# 1242 has been found in 8 queries.
# 718 has been found in 11 queries.
# 1014 has been found in 10 queries.
# 1001 has been found in 11 queries.
# 548 has been found in 10 queries.
# 1212 has been found in 11 queries.
# 1326 has been found in 11 queries.
# 1340 has been found in 11 queries.
# 485 has been found in 8 queries.
# 1375 has been found in 10 queries.
# 814 has been found in 10 queries.
# 803 has been found in 10 queries.
# 876 has been found in 11 queries.
# 908 has been found in 11 queries.
# 552 has been found in 9 queries.
# 476 has been found in 10 queries.
# 950 has been found in 9 queries.
# 808 has been found in 11 queries.
# 352 has been found in 11 queries.
# 390 has been found in 11 queries.
# 324 has been found in 9 queries.
# 1381 has been found in 6 queries.
# 1160 has been found in 11 queries.
# 513 has been found in 11 queries.
# 471 has been found in 11 queries.
# 1531 has been found in 10 queries.
# 647 has been found in 10 queries.
# 1191 has been found in 11 queries.
# 34 has been found in 10 queries.
# 174 has been found in 6 queries.
# 1350 has been found in 10 queries.
# 1226 has been found in 11 queries.
# 293 has been found in 11 queries.
# 225 has been found in 7 queries.
# 1389 has been found in 9 queries.
# 85 has been found in 8 queries.
# 1326 has been found in 11 queries.
# 1675 has been found in 9 queries.
# 1181 has been found in 10 queries.
# 1338 has been found in 10 queries.
# 810 has been found in 11 queries.
# 1444 has been found in 10 queries.
# 126 has been found in 7 queries.
# 1610 has been found in 10 queries.
# 436 has been found in 11 queries.
# 1087 has been found in 11 queries.
# 553 has been found in 11 queries.
# 120 has been found in 10 queries.
# 828 has been found in 7 queries.
# 233 has been found in 11 queries.
# 690 has been found in 11 queries.
# 1610 has been found in 10 queries.
# 1833 has been found in 10 queries.
# 1776 has been found in 9 queries.
# 1746 has been found in 9 queries.
# 1018 has been found in 9 queries.
# 599 has been found in 8 queries.
# 1662 has been found in 10 queries.
# 113 has been found in 11 queries.
# 459 has been found in 7 queries.
# 1482 has been found in 11 queries.
# 1295 has been found in 10 queries.
# 65 has been found in 9 queries.
# 1343 has been found in 11 queries.
# 1042 has been found in 11 queries.
# 1132 has been found in 11 queries.
# 1462 has been found in 11 queries.
# 1678 has been found in 8 queries.
# 1493 has been found in 10 queries.
# 692 has been found in 11 queries.
# 1299 has been found in 9 queries.
# 882 has been found in 11 queries.
# 986 has been found in 11 queries.
# 974 has been found in 8 queries.
# 581 has been found in 11 queries.
# 1672 has been found in 6 queries.
# 648 has been found in 10 queries.
# 1136 has been found in 10 queries.
# 463 has been found in 11 queries.
# 684 has been found in 11 queries.
# 1331 has been found in 9 queries.
# 1256 has been found in 11 queries.
# 1937 has been found in 11 queries.
# 1448 has been found in 10 queries.
# 1057 has been found in 10 queries.
# 840 has been found in 12 queries.
# 864 has been found in 10 queries.
# 448 has been found in 11 queries.
# 358 has been found in 12 queries.
# 2153 has been found in 10 queries.
# 1835 has been found in 11 queries.
# 1215 has been found in 10 queries.
# 518 has been found in 11 queries.
# 1770 has been found in 10 queries.
# 224 has been found in 8 queries.
# 455 has been found in 11 queries.
# 458 has been found in 11 queries.
# 1701 has been found in 9 queries.
# 249 has been found in 11 queries.
# 790 has been found in 11 queries.
# 1119 has been found in 10 queries.
# 1589 has been found in 8 queries.
# 637 has been found in 11 queries.
# 1063 has been found in 11 queries.
# 1420 has been found in 11 queries.
# 1180 has been found in 7 queries.
# 976 has been found in 10 queries.
# 2344 has been found in 10 queries.
# 161 has been found in 11 queries.
# 1717 has been found in 11 queries.
# 1122 has been found in 11 queries.
# 2305 has been found in 7 queries.
# 1999 has been found in 12 queries.
# 263 has been found in 8 queries.
# 1168 has been found in 11 queries.
# 649 has been found in 11 queries.
# 997 has been found in 11 queries.
# 187 has been found in 10 queries.
# 676 has been found in 12 queries.
# 1590 has been found in 8 queries.
# 37 has been found in 11 queries.
# 316 has been found in 9 queries.
# 2470 has been found in 12 queries.
# 343 has been found in 12 queries.
# 442 has been found in 10 queries.
# 2354 has been found in 12 queries.
# 795 has been found in 9 queries.
# 2227 has been found in 9 queries.
# 2418 has been found in 11 queries.
# 555 has been found in 12 queries.
# 2468 has been found in 10 queries.
# 267 has been found in 12 queries.
# 624 has been found in 12 queries.
# 1873 has been found in 10 queries.
# 1369 has been found in 12 queries.
# 826 has been found in 9 queries.
# 2297 has been found in 7 queries.
# 2087 has been found in 7 queries.
# 1010 has been found in 12 queries.
# 1829 has been found in 12 queries.
# 2044 has been found in 12 queries.
# 905 has been found in 7 queries.
# 979 has been found in 12 queries.
# 1018 has been found in 10 queries.
# 2601 has been found in 12 queries.
# 1244 has been found in 12 queries.
# 236 has been found in 10 queries.
# 1030 has been found in 11 queries.
# 1143 has been found in 12 queries.
# 563 has been found in 12 queries.
# 1109 has been found in 11 queries.
# 1777 has been found in 12 queries.
# 2273 has been found in 11 queries.
# 2513 has been found in 7 queries.
# 1395 has been found in 11 queries.
# 353 has been found in 10 queries.
# 1765 has been found in 6 queries.
# 1894 has been found in 12 queries.
# 227 has been found in 11 queries.
# 2829 has been found in 12 queries.
# 485 has been found in 8 queries.
# 1873 has been found in 11 queries.
# 972 has been found in 11 queries.
# 30 has been found in 12 queries.
# 61 has been found in 11 queries.
# 1905 has been found in 10 queries.
# 1219 has been found in 10 queries.
# 2887 has been found in 9 queries.
# 2466 has been found in 11 queries.
# 593 has been found in 10 queries.
# 1756 has been found in 7 queries.
# 1709 has been found in 7 queries.
# 844 has been found in 11 queries.
# 1691 has been found in 11 queries.
# 2989 has been found in 8 queries.
# 91 has been found in 11 queries.
# 668 has been found in 11 queries.
# 737 has been found in 8 queries.
# 1827 has been found in 11 queries.
# 2843 has been found in 12 queries.
# 441 has been found in 9 queries.
# 2746 has been found in 12 queries.
# 461 has been found in 8 queries.
# 2232 has been found in 12 queries.
# 1558 has been found in 10 queries.
# 1081 has been found in 11 queries.
# 2007 has been found in 12 queries.
# 2426 has been found in 12 queries.
# 2387 has been found in 11 queries.
# 2206 has been found in 11 queries.
# 1984 has been found in 11 queries.
# 199 has been found in 4 queries.
# 1106 has been found in 12 queries.
# 908 has been found in 11 queries.
# 2906 has been found in 12 queries.
# 84 has been found in 11 queries.
# 732 has been found in 12 queries.
# 2141 has been found in 10 queries.
# 1409 has been found in 9 queries.
# 1313 has been found in 7 queries.
# 1917 has been found in 11 queries.
# 556 has been found in 10 queries.
# 2801 has been found in 11 queries.
# 1586 has been found in 11 queries.
# 311 has been found in 9 queries.
# 2929 has been found in 10 queries.
# 554 has been found in 11 queries.
# 897 has been found in 12 queries.
# 1435 has been found in 12 queries.
# 3328 has been found in 12 queries.
# 2334 has been found in 11 queries.
# 2985 has been found in 11 queries.
# 548 has been found in 12 queries.
# 2086 has been found in 12 queries.
# 1969 has been found in 12 queries.
# 2559 has been found in 12 queries.
# 289 has been found in 12 queries.
# 409 has been found in 7 queries.
# 1733 has been found in 11 queries.
# 2390 has been found in 12 queries.
# 1931 has been found in 12 queries.
# 1227 has been found in 12 queries.
# 1230 has been found in 11 queries.
# 3493 has been found in 9 queries.
# 2049 has been found in 12 queries.
# 1823 has been found in 10 queries.
# 906 has been found in 9 queries.
# 1153 has been found in 11 queries.
# 1816 has been found in 10 queries.
# 1664 has been found in 12 queries.
# 3563 has been found in 9 queries.
# 22 has been found in 11 queries.
# 1701 has been found in 12 queries.
# 1730 has been found in 12 queries.
# 2199 has been found in 12 queries.
# 3279 has been found in 11 queries.
# 2921 has been found in 10 queries.
# 1386 has been found in 3 queries.
# 992 has been found in 12 queries.
# 3400 has been found in 12 queries.
# 1883 has been found in 12 queries.
# 331 has been found in 8 queries.
# 748 has been found in 12 queries.
# 424 has been found in 12 queries.
# 495 has been found in 9 queries.
# 1600 has been found in 12 queries.
# 3598 has been found in 12 queries.
# 2784 has been found in 12 queries.
# 1806 has been found in 12 queries.
# 1249 has been found in 12 queries.
# 1648 has been found in 12 queries.
# 595 has been found in 10 queries.
# 2412 has been found in 9 queries.
# 2287 has been found in 12 queries.
# 3447 has been found in 12 queries.
# 119 has been found in 11 queries.
# 686 has been found in 12 queries.
# 1603 has been found in 11 queries.
# 3442 has been found in 11 queries.
# 2777 has been found in 12 queries.
# 3422 has been found in 10 queries.
# 1871 has been found in 12 queries.
# 2371 has been found in 12 queries.
# 559 has been found in 11 queries.
# 517 has been found in 12 queries.
# 1517 has been found in 12 queries.
# 2377 has been found in 10 queries.
# 103 has been found in 12 queries.
# 1832 has been found in 11 queries.
# 1594 has been found in 11 queries.
# 3317 has been found in 12 queries.
# 3171 has been found in 12 queries.
# 3093 has been found in 12 queries.
# 2710 has been found in 12 queries.
# 3190 has been found in 10 queries.
# 454 has been found in 11 queries.
# 3143 has been found in 12 queries.
# 2052 has been found in 12 queries.
# 3648 has been found in 11 queries.
# 3645 has been found in 12 queries.
# 2501 has been found in 10 queries.
# 2891 has been found in 11 queries.
# 820 has been found in 11 queries.
# 1027 has been found in 12 queries.
# 3971 has been found in 12 queries.
# 4008 has been found in 12 queries.
# 437 has been found in 10 queries.
# 830 has been found in 10 queries.
# 3391 has been found in 12 queries.
# 3317 has been found in 12 queries.
# 4036 has been found in 11 queries.
# 1561 has been found in 10 queries.
# 1846 has been found in 7 queries.
# 2120 has been found in 12 queries.
# 923 has been found in 12 queries.
# 1190 has been found in 13 queries.
# 1693 has been found in 12 queries.
# 3227 has been found in 12 queries.
# 509 has been found in 11 queries.
# 4125 has been found in 10 queries.
# 2459 has been found in 12 queries.
# 3629 has been found in 12 queries.
# 3705 has been found in 12 queries.
# 1469 has been found in 11 queries.
# 3333 has been found in 7 queries.
# 514 has been found in 7 queries.
# 3809 has been found in 10 queries.
# 2809 has been found in 12 queries.
# 1647 has been found in 12 queries.
# 2033 has been found in 12 queries.
# 892 has been found in 6 queries.
# 2354 has been found in 12 queries.
# 2147 has been found in 10 queries.
# 4204 has been found in 12 queries.
# 3912 has been found in 12 queries.
# 2629 has been found in 12 queries.
# 4008 has been found in 11 queries.
# 872 has been found in 12 queries.
# 3819 has been found in 12 queries.
# 3760 has been found in 7 queries.
# 2311 has been found in 12 queries.
# 2300 has been found in 13 queries.
# 3732 has been found in 12 queries.
# 325 has been found in 12 queries.
# 3061 has been found in 13 queries.
# 2336 has been found in 11 queries.
# 3256 has been found in 12 queries.
# 2423 has been found in 13 queries.
# 4224 has been found in 12 queries.
# 116 has been found in 9 queries.
# 3825 has been found in 13 queries.
# 1785 has been found in 13 queries.
# 1883 has been found in 12 queries.
# 825 has been found in 12 queries.
# 2541 has been found in 12 queries.
# 2508 has been found in 10 queries.
# 3120 has been found in 12 queries.
# 2144 has been found in 12 queries.
# 1465 has been found in 12 queries.
# 104 has been found in 10 queries.
# 399 has been found in 12 queries.
# 2366 has been found in 13 queries.
# 996 has been found in 10 queries.
# 2624 has been found in 6 queries.
# 516 has been found in 11 queries.
# 3713 has been found in 11 queries.
# 3184 has been found in 12 queries.
# 633 has been found in 11 queries.
# 92 has been found in 8 queries.
# 132 has been found in 11 queries.
# 2883 has been found in 11 queries.
# 4282 has been found in 13 queries.
# 1713 has been found in 11 queries.
# 4605 has been found in 13 queries.
# 4594 has been found in 11 queries.
# 3379 has been found in 12 queries.
# 1220 has been found in 12 queries.
# 1415 has been found in 7 queries.
# 3504 has been found in 13 queries.
# 1727 has been found in 11 queries.
# 3017 has been found in 10 queries.
# 353 has been found in 9 queries.
# 2115 has been found in 12 queries.
# 3265 has been found in 10 queries.
# 287 has been found in 10 queries.
# 3752 has been found in 12 queries.
# 2707 has been found in 13 queries.
# 1029 has been found in 12 queries.
# 1014 has been found in 6 queries.
# 3097 has been found in 12 queries.
# 839 has been found in 12 queries.
# 2586 has been found in 9 queries.
# 4267 has been found in 12 queries.
# 3213 has been found in 12 queries.
# 4231 has been found in 9 queries.
# 2769 has been found in 11 queries.
# 2876 has been found in 9 queries.
# 1578 has been found in 12 queries.
# 4473 has been found in 12 queries.
# 3189 has been found in 12 queries.
# 2564 has been found in 12 queries.
# 2348 has been found in 13 queries.
# 3034 has been found in 13 queries.
# 2071 has been found in 12 queries.
# 4559 has been found in 9 queries.
# 4123 has been found in 11 queries.
# 1310 has been found in 12 queries.
# 3402 has been found in 11 queries.
# 1499 has been found in 12 queries.
# 1881 has been found in 13 queries.
# 2872 has been found in 9 queries.
# 2890 has been found in 11 queries.
# 2730 has been found in 13 queries.
# 3971 has been found in 11 queries.
# 5125 has been found in 12 queries.
# 3393 has been found in 6 queries.
# 2580 has been found in 13 queries.
# 824 has been found in 11 queries.
# 3655 has been found in 12 queries.
# 2204 has been found in 11 queries.
# 3411 has been found in 12 queries.
# 4912 has been found in 12 queries.
# 5333 has been found in 12 queries.
# 1531 has been found in 13 queries.
# 2665 has been found in 13 queries.
# 1413 has been found in 12 queries.
# 4624 has been found in 12 queries.
# 3079 has been found in 12 queries.
# 1755 has been found in 12 queries.
# 4242 has been found in 13 queries.
# 4830 has been found in 12 queries.
# 4666 has been found in 12 queries.
# 3247 has been found in 10 queries.
# 678 has been found in 11 queries.
# 3314 has been found in 11 queries.
# 4098 has been found in 13 queries.
# 1127 has been found in 12 queries.
# 3382 has been found in 9 queries.
# 1347 has been found in 12 queries.
# 5356 has been found in 11 queries.
# 935 has been found in 11 queries.
# 4775 has been found in 11 queries.
# 4670 has been found in 12 queries.
# 359 has been found in 9 queries.
# 1769 has been found in 13 queries.
# 3562 has been found in 12 queries.
# 2363 has been found in 11 queries.
# 2350 has been found in 9 queries.
# 4167 has been found in 12 queries.
# 5270 has been found in 8 queries.
# 381 has been found in 9 queries.
# 3737 has been found in 12 queries.
# 685 has been found in 13 queries.
# 5378 has been found in 12 queries.
# 2249 has been found in 11 queries.
# 5484 has been found in 12 queries.
# 4144 has been found in 10 queries.
# 140 has been found in 13 queries.
# 119 has been found in 11 queries.
# 1556 has been found in 13 queries.
# 3695 has been found in 12 queries.
# 4284 has been found in 13 queries.
# 716 has been found in 12 queries.
# 4692 has been found in 13 queries.
# 2755 has been found in 13 queries.
# 684 has been found in 12 queries.
# 1384 has been found in 13 queries.
# 2987 has been found in 12 queries.
# 1957 has been found in 9 queries.
# 106 has been found in 10 queries.
# 139 has been found in 13 queries.
# 3865 has been found in 13 queries.
# 1605 has been found in 13 queries.
# 1871 has been found in 12 queries.
# 1753 has been found in 12 queries.
# 5244 has been found in 11 queries.
# 5756 has been found in 13 queries.
# 4905 has been found in 12 queries.
# 2589 has been found in 12 queries.
# 2813 has been found in 12 queries.
# 5012 has been found in 13 queries.
# 3768 has been found in 13 queries.
# 195 has been found in 11 queries.
# 5662 has been found in 12 queries.
# 1846 has been found in 13 queries.
# 904 has been found in 12 queries.
# 2108 has been found in 7 queries.
# 1548 has been found in 12 queries.
# 3229 has been found in 13 queries.
# 5013 has been found in 13 queries.
# 5786 has been found in 13 queries.
# 2073 has been found in 12 queries.
# 4620 has been found in 13 queries.
# 5465 has been found in 13 queries.
# 656 has been found in 13 queries.
# 5234 has been found in 10 queries.
# 1839 has been found in 10 queries.
# 2161 has been found in 12 queries.
# 4298 has been found in 13 queries.
# 133 has been found in 11 queries.
# 5068 has been found in 12 queries.
# 1497 has been found in 11 queries.
# 2838 has been found in 10 queries.
# 2254 has been found in 11 queries.
# 5737 has been found in 13 queries.
# 5423 has been found in 13 queries.
# 5160 has been found in 11 queries.
# 3614 has been found in 12 queries.
# 5583 has been found in 11 queries.
# 4488 has been found in 11 queries.
# 1764 has been found in 12 queries.
# 36 has been found in 9 queries.
# 4237 has been found in 10 queries.
# 3916 has been found in 13 queries.
# 4047 has been found in 12 queries.
# 2870 has been found in 13 queries.
# 888 has been found in 11 queries.
# 294 has been found in 6 queries.
# 4920 has been found in 5 queries.
# 2171 has been found in 12 queries.
# 775 has been found in 12 queries.
# 4112 has been found in 12 queries.
# 464 has been found in 11 queries.
# 4182 has been found in 13 queries.
# 4630 has been found in 10 queries.
# 3854 has been found in 13 queries.
# 2339 has been found in 11 queries.
# 986 has been found in 9 queries.
# 4406 has been found in 12 queries.
# 924 has been found in 8 queries.
# 4780 has been found in 10 queries.
# 5462 has been found in 12 queries.
# 3649 has been found in 12 queries.
# 5234 has been found in 13 queries.
# 5675 has been found in 13 queries.
# 2053 has been found in 12 queries.
# 6152 has been found in 12 queries.
# 5197 has been found in 12 queries.
# 1543 has been found in 11 queries.
# 5024 has been found in 12 queries.
# 3936 has been found in 11 queries.
# 5538 has been found in 13 queries.
# 6395 has been found in 11 queries.
# 177 has been found in 13 queries.
# 4871 has been found in 8 queries.
# 2040 has been found in 13 queries.
# 2344 has been found in 8 queries.
# 2586 has been found in 11 queries.
# 6424 has been found in 12 queries.
# 5952 has been found in 12 queries.
# 2681 has been found in 12 queries.
# 2077 has been found in 12 queries.
# 4162 has been found in 11 queries.
# 1375 has been found in 11 queries.
# 4876 has been found in 13 queries.
# 4161 has been found in 13 queries.
# 3391 has been found in 11 queries.
# 2433 has been found in 12 queries.
# 2632 has been found in 12 queries.
# 2282 has been found in 13 queries.
# 2002 has been found in 13 queries.
# 73 has been found in 13 queries.
# 1461 has been found in 13 queries.
# 1114 has been found in 7 queries.
# 6120 has been found in 13 queries.
# 2009 has been found in 13 queries.
# 5493 has been found in 11 queries.
# 2336 has been found in 5 queries.
# 6690 has been found in 12 queries.
# 842 has been found in 10 queries.
# 5327 has been found in 11 queries.
# 738 has been found in 11 queries.
# 249 has been found in 12 queries.
# 5319 has been found in 12 queries.
# 4399 has been found in 13 queries.
# 3528 has been found in 13 queries.
# 104 has been found in 13 queries.
# 1722 has been found in 12 queries.
# 1641 has been found in 12 queries.
# 3921 has been found in 13 queries.
# 887 has been found in 13 queries.
# 964 has been found in 13 queries.
# 6599 has been found in 12 queries.
# 6340 has been found in 12 queries.
# 6203 has been found in 12 queries.
# 3844 has been found in 12 queries.
# 2464 has been found in 13 queries.
# 2407 has been found in 13 queries.
# 5515 has been found in 12 queries.
# 4154 has been found in 13 queries.
# 5414 has been found in 13 queries.
# 1241 has been found in 13 queries.
# 397 has been found in 11 queries.
# 2125 has been found in 13 queries.
# 1263 has been found in 11 queries.
# 1838 has been found in 11 queries.
# 1378 has been found in 10 queries.
# 6675 has been found in 10 queries.
# 1525 has been found in 12 queries.
# 2768 has been found in 11 queries.
# 4746 has been found in 12 queries.
# 248 has been found in 8 queries.
# 242 has been found in 13 queries.
# 6017 has been found in 7 queries.
# 2929 has been found in 12 queries.
# 6182 has been found in 11 queries.
# 5741 has been found in 12 queries.
# 2602 has been found in 13 queries.
# 2478 has been found in 13 queries.
# 4871 has been found in 10 queries.
# 1664 has been found in 13 queries.
# 1759 has been found in 11 queries.
# 6708 has been found in 13 queries.
# 2642 has been found in 13 queries.
# 1617 has been found in 10 queries.
# 6378 has been found in 10 queries.
# 3222 has been found in 13 queries.
# 4940 has been found in 13 queries.
# 408 has been found in 13 queries.
# 3480 has been found in 11 queries.
# 13 has been found in 13 queries.
# 1830 has been found in 13 queries.
# 4781 has been found in 13 queries.
# 1899 has been found in 13 queries.
# 1278 has been found in 12 queries.
# 481 has been found in 12 queries.
# 2959 has been found in 12 queries.
# 3706 has been found in 10 queries.
# 3159 has been found in 11 queries.
# 4333 has been found in 13 queries.
# 3206 has been found in 13 queries.
# 2836 has been found in 12 queries.
# 1333 has been found in 13 queries.
# 5346 has been found in 13 queries.
# 5726 has been found in 9 queries.
# 5173 has been found in 13 queries.
# 1590 has been found in 11 queries.
# 6758 has been found in 13 queries.
# 5050 has been found in 13 queries.
# 3348 has been found in 11 queries.
# 6237 has been found in 13 queries.
# 6471 has been found in 13 queries.
# 3813 has been found in 9 queries.
# 5939 has been found in 11 queries.
# 2863 has been found in 9 queries.
# 6333 has been found in 13 queries.
# 5191 has been found in 13 queries.
# 1031 has been found in 12 queries.
# 5058 has been found in 12 queries.
# 5166 has been found in 13 queries.
# 5856 has been found in 13 queries.
# 5696 has been found in 13 queries.
# 6033 has been found in 13 queries.
# 687 has been found in 11 queries.
# 1772 has been found in 13 queries.
# 6545 has been found in 12 queries.
# 4160 has been found in 11 queries.
# 204 has been found in 12 queries.
# 1980 has been found in 11 queries.
# 2326 has been found in 13 queries.
# 2361 has been found in 13 queries.
# 4835 has been found in 12 queries.
# 3447 has been found in 13 queries.
# 2073 has been found in 11 queries.
# 2739 has been found in 12 queries.
# 5331 has been found in 12 queries.
# 1265 has been found in 13 queries.
# 853 has been found in 12 queries.
# 1584 has been found in 12 queries.
# 4683 has been found in 10 queries.
# 6983 has been found in 13 queries.
# 1933 has been found in 9 queries.
# 7583 has been found in 13 queries.
# 3654 has been found in 13 queries.
# 2956 has been found in 13 queries.
# 3629 has been found in 13 queries.
# 4895 has been found in 12 queries.
# 569 has been found in 9 queries.
# 230 has been found in 9 queries.
# 978 has been found in 13 queries.
# 7091 has been found in 13 queries.
# 2990 has been found in 13 queries.
# 2196 has been found in 13 queries.
# 7862 has been found in 11 queries.
# 6630 has been found in 13 queries.
# 3763 has been found in 13 queries.
# 5311 has been found in 7 queries.
# 5758 has been found in 12 queries.
# 1823 has been found in 13 queries.
# 5312 has been found in 12 queries.
# 7339 has been found in 13 queries.
# 5535 has been found in 12 queries.
# 4060 has been found in 11 queries.
# 7678 has been found in 10 queries.
# 4761 has been found in 13 queries.
# 4801 has been found in 13 queries.
# 5893 has been found in 12 queries.
# 58 has been found in 13 queries.
# 2266 has been found in 13 queries.
# 1993 has been found in 13 queries.
# 3743 has been found in 11 queries.
# 7851 has been found in 13 queries.
# 6395 has been found in 12 queries.
# 1697 has been found in 13 queries.
# 1266 has been found in 12 queries.
# 3858 has been found in 9 queries.
# 1648 has been found in 9 queries.
# 6320 has been found in 13 queries.
# 5868 has been found in 10 queries.
# 7533 has been found in 13 queries.
# 2960 has been found in 13 queries.
# 5837 has been found in 13 queries.
# 2422 has been found in 13 queries.
# 6392 has been found in 13 queries.
# 929 has been found in 12 queries.
# 3036 has been found in 13 queries.
# 6489 has been found in 12 queries.
# 4613 has been found in 13 queries.
# 6830 has been found in 10 queries.
# 6674 has been found in 12 queries.
# 4936 has been found in 12 queries.
# 5947 has been found in 9 queries.
# 627 has been found in 13 queries.
# 629 has been found in 13 queries.
# 5501 has been found in 13 queries.
# 4245 has been found in 12 queries.
# 8372 has been found in 12 queries.
# 433 has been found in 10 queries.
# 2173 has been found in 13 queries.
# 5898 has been found in 12 queries.
# 2315 has been found in 11 queries.
# 4215 has been found in 9 queries.
# 7671 has been found in 11 queries.
# 299 has been found in 13 queries.
# 8487 has been found in 13 queries.
# 3532 has been found in 13 queries.
# 928 has been found in 14 queries.
# 6664 has been found in 13 queries.
# 6234 has been found in 12 queries.
# 1148 has been found in 11 queries.
# 4737 has been found in 10 queries.
# 5628 has been found in 13 queries.
# 8441 has been found in 13 queries.
# 8495 has been found in 13 queries.
# 942 has been found in 13 queries.
# 3218 has been found in 13 queries.
# 6118 has been found in 12 queries.
# 3583 has been found in 10 queries.
# 6837 has been found in 13 queries.
# 6985 has been found in 14 queries.
# 3634 has been found in 10 queries.
# 1284 has been found in 13 queries.
# 6810 has been found in 13 queries.
# 6471 has been found in 13 queries.
# 7922 has been found in 13 queries.
# 6498 has been found in 10 queries.
# 6388 has been found in 6 queries.
# 2214 has been found in 13 queries.
# 6544 has been found in 11 queries.
# 3406 has been found in 13 queries.
# 929 has been found in 11 queries.
# 2158 has been found in 13 queries.
# 7948 has been found in 13 queries.
# 106 has been found in 11 queries.
# 5835 has been found in 12 queries.
# 1200 has been found in 14 queries.
# 6780 has been found in 12 queries.
# 7730 has been found in 12 queries.
# 8752 has been found in 13 queries.
# 5632 has been found in 13 queries.
# 6695 has been found in 13 queries.
# 5895 has been found in 12 queries.
# 5803 has been found in 14 queries.
# 4139 has been found in 11 queries.
# 2951 has been found in 13 queries.
# 4089 has been found in 13 queries.
# 6722 has been found in 12 queries.
# 7815 has been found in 11 queries.
# 607 has been found in 9 queries.
# 2312 has been found in 12 queries.
# 2484 has been found in 9 queries.
# 2670 has been found in 11 queries.
# 2417 has been found in 12 queries.
# 80 has been found in 12 queries.
# 1762 has been found in 12 queries.
# 4857 has been found in 13 queries.
# 2099 has been found in 10 queries.
# 2915 has been found in 14 queries.
# 183 has been found in 10 queries.
# 7596 has been found in 11 queries.
# 2032 has been found in 11 queries.
# 8890 has been found in 12 queries.
# 6312 has been found in 11 queries.
# 8436 has been found in 13 queries.
# 6099 has been found in 13 queries.
# 3200 has been found in 13 queries.
# 3656 has been found in 12 queries.
# 2038 has been found in 13 queries.
# 1261 has been found in 9 queries.
# 5151 has been found in 14 queries.
# 2009 has been found in 13 queries.
# 141 has been found in 14 queries.
# 1347 has been found in 13 queries.
# 7016 has been found in 13 queries.
# 1915 has been found in 13 queries.
# 2536 has been found in 11 queries.
# 286 has been found in 14 queries.
# 2768 has been found in 12 queries.
# 8801 has been found in 13 queries.
# 7453 has been found in 12 queries.
# 1762 has been found in 13 queries.
# 70 has been found in 14 queries.
# 2136 has been found in 11 queries.
# 9121 has been found in 13 queries.
# 3291 has been found in 12 queries.
# 4071 has been found in 11 queries.
# 3087 has been found in 13 queries.
# 2167 has been found in 14 queries.
# 7574 has been found in 13 queries.
# 8572 has been found in 13 queries.
# 9080 has been found in 7 queries.
# 3190 has been found in 11 queries.
# 5323 has been found in 13 queries.
# 1651 has been found in 13 queries.
# 6215 has been found in 13 queries.
# 6879 has been found in 13 queries.
# 8845 has been found in 13 queries.
# 2898 has been found in 14 queries.
# 1465 has been found in 13 queries.
# 1830 has been found in 13 queries.
# 8365 has been found in 11 queries.
# 6096 has been found in 13 queries.
# 6322 has been found in 12 queries.
# 6043 has been found in 13 queries.
# 5742 has been found in 12 queries.
# 8167 has been found in 13 queries.
# 375 has been found in 13 queries.
# 3681 has been found in 10 queries.
# 3704 has been found in 11 queries.
# 7375 has been found in 12 queries.
# 9141 has been found in 13 queries.
# 7886 has been found in 13 queries.
# 938 has been found in 12 queries.
# 5027 has been found in 13 queries.
# 5250 has been found in 13 queries.
# 7336 has been found in 12 queries.
# 3462 has been found in 11 queries.
# 89 has been found in 12 queries.
# 2108 has been found in 10 queries.
# 1283 has been found in 10 queries.
# 5788 has been found in 13 queries.
# 6951 has been found in 13 queries.
# 3001 has been found in 10 queries.
# 9458 has been found in 12 queries.
# 9234 has been found in 13 queries.
# 4327 has been found in 13 queries.
# 5428 has been found in 12 queries.
# 1691 has been found in 12 queries.
# 2835 has been found in 11 queries.
# 8823 has been found in 12 queries.
# 4808 has been found in 12 queries.
# 8180 has been found in 12 queries.
# 123 has been found in 10 queries.
# 7198 has been found in 13 queries.
# 6214 has been found in 11 queries.
# 555 has been found in 13 queries.
# 2412 has been found in 12 queries.
# 7127 has been found in 10 queries.
# 1291 has been found in 13 queries.
# 5807 has been found in 10 queries.
# 788 has been found in 11 queries.
# 353 has been found in 10 queries.
# 2253 has been found in 13 queries.
# 9692 has been found in 12 queries.
# 5134 has been found in 13 queries.
# 6451 has been found in 11 queries.
# 4555 has been found in 14 queries.
# 2822 has been found in 13 queries.
# 9354 has been found in 12 queries.
# 2781 has been found in 13 queries.
# 6962 has been found in 13 queries.
# 4988 has been found in 13 queries.
# []

# %% [markdown]
# #### **Problem #2.5**
#
# **Together**, let's graph the worst number of queries for list sizes from 100 to 10000 *for both linear and binary search*.

# %%
linear_queries = []
binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  # COMPLETE THIS CODE

plt.scatter(ns, linear_queries, label = "linear")
plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear and Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
#   File "<ipython-input-36-6a3b8be9e6f3>", line 7
#     plt.scatter(ns, linear_queries, label = "linear")
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# ###### **Solution**

# %%
linear_queries = []
binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  linear_queries += [linear_search(n)]
  binary_queries += [binary_search(n)]

plt.scatter(ns, linear_queries, label = "linear")
plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear and Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-9a2b5a85dbbe> in <module>
#       4 for n in ns:
#       5   linear_queries += [linear_search(n)]
# ----> 6   binary_queries += [binary_search(n)]
#       7
#       8 plt.scatter(ns, linear_queries, label = "linear")
#
# NameError: name 'binary_search' is not defined

# %% [markdown]
# #### **Problem  #2.6**
#
# **Together**, let's see how the performance of binary and linear search change when the order of items in the list is random using the `random.sample(...)` function. We will do this in 3 steps:
#
# 1. Rewrite the `linear_search` function so that the list is randomly ordered.
# 2. Rewrite the `binary_search` function so that the list is randomly ordered.
# 3. Graph the average number of queries for both search algorithms.
#
# ---

# %% [markdown]
# ##### **Problem 2.6.1**
# Rewrite the `linear_search` function so that the list is randomly ordered.

# %%
def linear_search(n):

  number_trials = 10
  worst_query = 0
  list_items = # COMPLETE THIS LINE

  for i in range(number_trials):

    marked_item = random.choice(list_items)
    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      if item == marked_item:
        #print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# ###### **Solution**

# %%
def linear_search(n):

  number_trials = 10
  worst_query = 0
  list_items = random.sample(range(n), n)

  for i in range(number_trials):

    marked_item = random.choice(list_items)
    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      if item == marked_item:
        #print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# ##### **Problem #2.6.2**
# Rewrite the `binary_search` function so that the list is randomly ordered.

# %%
def binary_search(n):

  number_trials = 10
  worst_query = 0
  list_items = # COMPLETE THIS LINE

  for i in range(number_trials):

    marked_item = random.choice(list_items)

    left = 0
    right = len(list_items) - 1

    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      middle = int((left + right)/2)
      if list_items[middle] > marked_item:
        right = middle
      elif list_items[middle] < marked_item:
        left = middle
      else:
        #print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# ###### **Solution**

# %%
def binary_search(n):

  number_trials = 10
  worst_query = 0
  list_items = random.sample(range(n), n)

  for i in range(number_trials):

    marked_item = random.choice(list_items)

    left = 0
    right = len(list_items) - 1

    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      middle = int((left + right)/2)
      if list_items[middle] > marked_item:
        right = middle
      elif list_items[middle] < marked_item:
        left = middle
      else:
        #print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# ##### **Problem #2.6.3**
# Graph the average number of queries for both search algorithms.

# %%
linear_queries = []
binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  # COMPLETE THIS CODE

plt.scatter(ns, linear_queries, label = "linear")
plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear and Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()

# %% [markdown]
# ###### **Solution**

# %%
linear_queries = []
binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  linear_queries += [linear_search(n)]
  binary_queries += [binary_search(n)]

plt.scatter(ns, linear_queries, label = "linear")
plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear and Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# []

# %% [markdown]
# #End of Lab
# ---
# © 2024 The Coding School, All rights reserved
